# %%
pip install xlrd
# Out:
# ...
#     100% |████████████████████████████████| 112kB 3.5MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df1 = pd.read_excel("./bitcoin_merged (since 2011, no NaN).xlsx")
df2 = pd.read_csv('reddit_daily_normalized.csv')
df3 = pd.read_csv('news_daily_normalized.csv')

# %%
df1.head()
# Out:
#          Date  Fees Value  Total Transactions  Daily Blocks  UTXO Set Size  \
# 0  2011-02-06        0.16              257460           179          84187
# 1  2011-02-07        0.09              258321           177          84405
# 2  2011-02-08        0.28              259209           203          84847
# 3  2011-02-09        0.16              260088           168          85255
# 4  2011-02-10        0.07              261334           192          85898
#
#    Velocity - Daily  Transaction Amount  Money Supply  Miner Revenue Value  \
# 0          0.015426           89.558963     5321500.0              7965.66
# 1          0.011643          136.429085     5330350.0              7876.59
# 2          0.029014          421.519826     5340500.0              8932.28
# 3          0.012668           58.934909     5348900.0              7644.16
# 4          0.024524           98.518699     5358500.0              9888.07
#
# ...

# %%
df2.head()
# Out:
#          Date  r_tit_subj_comm  r_tit_subj_score  r_tit_pol_comm  \
# 0  2010-12-01              0.0          0.232768        0.503682
# 1  2010-12-11              0.0          0.000000        0.503682
# 2  2011-02-10              0.0          0.000000        0.503682
# 3  2011-02-20              0.0          0.000000        0.503682
# 4  2011-03-21              0.0          0.000000        0.503682
#
#    r_tit_pol_score  r_bod_subj_comm  r_bod_subj_score  r_bod_pol_comm  \
# 0         0.672098              0.0          0.000000        0.143363
# 1         0.672098              0.0          0.000000        0.143363
# 2         0.672098              0.0          0.000000        0.143363
# 3         0.672098              0.0          0.127635        0.143363
# 4         0.672098              0.0          0.174176        0.143363
#
#    r_bod_pol_score  count
# 0         0.370165    0.0
# 1         0.370165    0.0
# 2         0.370165    0.0
# 3         0.374463    0.0
# ...

# %%
df3.describe()
# Out:
#        n_tit_subj_comm  n_tit_subj_score  n_tit_pol_comm  n_tit_pol_score  \
# count       507.000000        507.000000      507.000000       507.000000
# mean          0.100128          0.072917        0.608940         0.466257
# std           0.149044          0.108020        0.035769         0.032888
# min           0.000000          0.000000        0.000000         0.000000
# 25%           0.000000          0.000000        0.608310         0.465392
# 50%           0.029968          0.052810        0.608310         0.465392
# 75%           0.147814          0.098901        0.608387         0.465437
# max           1.000000          1.000000        1.000000         1.000000
#
#             count
# count  507.000000
# mean     0.138334
# std      0.225207
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.414913
# max      1.000000

# %%
# df2['Date'] = df2['date']

# df2.drop('date', axis = 1, inplace=True)

# %%
df = df1.merge(df2, on='Date', how='left')

# %%
df = df.merge(df3, on='Date', how='left')

# %%
df = df.fillna(value = -1.0)

# %%
df.to_csv('bitcoin_plus_reddit_plus_news.csv')
